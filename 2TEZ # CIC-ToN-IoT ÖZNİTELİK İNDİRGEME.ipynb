# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
from matplotlib import pyplot as plt
import seaborn as sns


import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import time
start = time.time()
#read data in chunks of 1 million rows at a time
chunk1 = pd.read_csv('I:\\verisetleri\\CIC-ToN-IoT.csv',chunksize=1000000)



df= pd.concat(chunk1)

# %%
df.head()

# %%
df= df.drop(['Unnamed: 0'], axis=1)

# %%
import gc

gc.collect()

# %%
df.columns = df.columns.str.strip()
print("original length of df:", len(df))
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
# Out:
# original length of df: 5350583

# %%
# data split
from sklearn.model_selection import train_test_split
from collections import Counter
X= df.drop(['77'], axis=1)
y = df['77']

# %%
from sklearn.preprocessing import StandardScaler
scaled_features = StandardScaler().fit_transform(X.values)
X = pd.DataFrame(scaled_features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
import math
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
  from sklearn.decomposition import PCA
  import matplotlib.pyplot as plt
  import seaborn as sns
  from sklearn.utils import resample
# %matplotlib inline

  X_train_pca, y_train_pca = resample(X_train, y_train, random_state=42, stratify=y_train)
  pca = PCA(0.99)
  X_train_pca = pca.fit_transform(X_train_pca)

# %%
X_test_pca, y_test_pca = resample(X_test, y_test, random_state=42, stratify=y_test)
X_test_pca = pca.transform(X_test_pca)

# %%
X_train_pca.shape

# %%
pca.get_covariance()

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance

# %%
y_train_pca.head()

# %%
y_train_pca

# %%
print(sum(pca.explained_variance_ratio_))

# %%
columns = ['pca_comp_%i' % i for i in range(35)]
X_train2  = pd.DataFrame(X_train_pca, columns=columns)
X_train2.head()
# Out:
#    pca_comp_0  pca_comp_1  pca_comp_2  pca_comp_3  pca_comp_4  pca_comp_5  \
# 0    1.686645   -2.518228   -0.360819    0.273487    0.222953    1.015710
# 1   -3.228716   -0.904777   -0.682588    1.597005    1.005232   -0.333410
# 2   -3.261329   -1.279971   -0.366962    1.326220    0.813365   -2.045138
# 3   -3.674812   -0.989851    0.218968   -0.399767   -0.477718   -1.313496
# 4    8.490680    1.307956   -2.621786    1.202910   -0.720301    0.081204
#
#    pca_comp_6  pca_comp_7  pca_comp_8  pca_comp_9  ...  pca_comp_25  \
# 0    0.453701    1.822665   -0.273921    0.023955  ...     0.250557
# 1    3.114670    0.786737    0.903318   -0.013434  ...     0.096771
# 2    1.922899    0.484406    0.521629   -0.014539  ...     0.076571
# 3   -2.450594   -1.499535    0.202856   -0.019678  ...    -0.009080
# 4   -1.951495    2.241294   -1.269965   -0.002489  ...    -0.209461
#
#    pca_comp_26  pca_comp_27  pca_comp_28  pca_comp_29  pca_comp_30  \
# ...

# %%
columns = ['pca_comp_%i' % i for i in range(35)]
X_test2  = pd.DataFrame(X_test_pca, columns=columns)
X_test2.head()
# Out:
#    pca_comp_0  pca_comp_1  pca_comp_2  pca_comp_3  pca_comp_4  pca_comp_5  \
# 0   -3.508663   -0.996076    0.448884   -0.512250   -0.284021    0.652046
# 1   11.341112   -0.039392   -0.991609   -1.152301   -0.131065   -0.483173
# 2   -3.712986   -1.241832    0.152479   -0.180827    0.219096    2.537356
# 3   -3.236968   -0.715290   -0.708704    1.580165    1.012273    0.031961
# 4   -3.518645   -1.941708    0.276212   -0.142878    0.021121   -0.639669
#
#    pca_comp_6  pca_comp_7  pca_comp_8  pca_comp_9  ...  pca_comp_25  \
# 0   -0.539902    0.122800   -0.701063    0.002182  ...     0.010381
# 1    0.862912    0.397434   -0.646694   -0.034962  ...     0.412936
# 2    0.886164    0.481990   -0.118038    0.002471  ...    -0.042542
# 3    3.249267    0.817766    0.943949   -0.013879  ...     0.084151
# 4   -1.132389    0.548722   -0.999949    0.028110  ...    -0.084197
#
#    pca_comp_26  pca_comp_27  pca_comp_28  pca_comp_29  pca_comp_30  \
# ...

# %%
X_train= X_train2[["pca_comp_0", "pca_comp_11","pca_comp_6","pca_comp_9", "pca_comp_12","pca_comp_17", "pca_comp_21","pca_comp_1","pca_comp_13","pca_comp_14","pca_comp_34", "pca_comp_19","pca_comp_18","pca_comp_4","pca_comp_10"]]

# %%
X_test= X_test2[["pca_comp_0", "pca_comp_11","pca_comp_6","pca_comp_9", "pca_comp_12","pca_comp_17", "pca_comp_21","pca_comp_1","pca_comp_13","pca_comp_14","pca_comp_34", "pca_comp_19","pca_comp_18","pca_comp_4","pca_comp_10"]]

# %%
from imblearn.over_sampling import BorderlineSMOTE
oversample = BorderlineSMOTE()
X_resample, y_resample = oversample.fit_resample(X_train, y_train_pca)

# %%
X_train_pca.to_csv(r'I:\\verisetleri1\\CIC-ToN-IoT\\X_train.csv')
X_test_pca.to_csv(r'I:\\verisetleri1\\CIC-ToN-IoT\\X_test.csv')
Y_test.to_csv(r'I:\\verisetleri1\\CIC-ToN-IoT\\y_test.csv')
y_train_pca.to_csv(r'I:\\verisetleri1\\CIC-ToN-IoT\\y_train.csv')
